# %%
l1:list[int] = [1,2,3,4,5]
try:
 print(12/2)
 print(l1[0])
 print(xyz)
except (ZeroDivisionError) as e:
    print(f'Zero division error {e}') 

except (IndexError) as e:
    print(f'Index error {e}')

except (NameError) as e:
    print(f'Name error {e}')
    
except:
    print('something went wrong')
# Out:
# 6.0
# 1
# Name error name 'xyz' is not defined

# %%
try:
    # print(abc)
    print(l1[200])    
except Exception as e: #handle dynamic error using Exception class
    print(f'Something went wrong {e}')
# Out:
# Something went wrong list index out of range

# %% [markdown]
# # File handling

# %% [markdown]
# # mode
#
# * "r" - Read - Default value. Opens a file for reading, error if the file does not exist
#
# * "a" - Append - Opens a file for appending, creates the file if it does not exist
#
# * "w" - Write - Opens a file for writing, creates the file if it does not exist
#
# * "x" - Create - Creates the specified file, returns an error if the file exists
#
# * "t" - Text - Default value. Text mode
#
# * "b" - Binary - Binary mode (e.g. images)

# %%
from typing import TextIO
file : TextIO = open('../libraries.txt')
print(file.read())
file.close()
# Out:
# numpy
# pandas
# mypy

# %%
with open('../libraries.txt') as file:
    print(file.read())
# Out:
# numpy
# pandas
# mypy

# %%
with open('../libraries.txt') as file:
    print(file.readline(),end='') # read only one line at a time
    print(file.readline(),end='') # read only one line at a time
# Out:
# numpy
# pandas

# %%
with open('../libraries.txt') as file:
    print(file.readlines())
# Out:
# ['numpy\n', 'pandas\n', 'mypy\n']

# %%
with open('../libraries.txt','r') as file:
    print(file.readlines()[0:2])
# Out:
# ['numpy\n', 'pandas\n']

# %%
with open('../libraries.txt','w') as file:
    print(file.write('hello world'))
# Out:
# 11

# %%
with open('../libraries.txt','r+') as file:
    file.write(' how are you')
    print(file.read())
# Out:
# ou

# %%
with open('../libraries.txt','r+') as file:
    print(file.read())
    file.write(' how are you and what about you')
    file.seek(0)
    print('after', file.read())
# Out:
#  how are you and what about you
# after  how are you and what about you how are you and what about you

# %% [markdown]
# <table class="s-table">
# <thead>
# <tr>
# <th style="text-align: center;">Mode</th>
# <th style="text-align: center;">r</th>
# <th style="text-align: center;">r+</th>
# <th style="text-align: center;">w</th>
# <th style="text-align: center;">w+</th>
# <th style="text-align: center;">a</th>
# <th style="text-align: center;">a+</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align: center;">Read</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;">+</td>
# </tr>
# <tr>
# <td style="text-align: center;">Write</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# </tr>
# <tr>
# <td style="text-align: center;">Create</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# </tr>
# <tr>
# <td style="text-align: center;">Cover</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;"></td>
# </tr>
# <tr>
# <td style="text-align: center;">Point in the beginning</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;"></td>
# </tr>
# <tr>
# <td style="text-align: center;">Point in the end</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# # Read some real world data files
# * csv
# * image
# * pdf
# * live camera

# %%
import pandas as pd

df : pd.DataFrame = pd.read_csv('./data.csv')
# fil = filter(lambda x:x[3] , df)
# print(list(fil))
df
# Out:
#    id   name education
# 0   1  waqas        BS
# 1   2  haris    matric
# 2   3  arman    matric

# %%
# reading csv file
import csv

with open('./data.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['id', 'name', 'education']
# ['1', 'waqas', 'BS']
# ['2', 'haris', 'matric']
# ['3', 'arman', 'matric']

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpImg

img : mpImg = mpImg.imread('meal.jpg')
plt.imshow(img)

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.9.0-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.1-cp311-cp311-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.53.0-cp311-cp311-win_amd64.whl.metadata (165 kB)
#      ---------------------------------------- 0.0/165.5 kB ? eta -:--:--
#      ------- -------------------------------- 30.7/165.5 kB ? eta -:--:--
#      ------------- ----------------------- 61.4/165.5 kB 656.4 kB/s eta 0:00:01
#      ---------------------- ------------- 102.4/165.5 kB 737.3 kB/s eta 0:00:01
#      -----------------------------------  163.8/165.5 kB 756.6 kB/s eta 0:00:01
#      ------------------------------------ 165.5/165.5 kB 708.9 kB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.23 in d:\anaconda\envs\'py-11'\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\envs\'py-11'\lib\site-packages (from matplotlib) (23.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-10.3.0-cp311-cp311-win_amd64.whl.metadata (9.4 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\envs\'py-11'\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\anaconda\envs\'py-11'\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.0-cp311-cp311-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1/8.0 MB 1.9 MB/s eta 0:00:05
#     --------------------------------------- 0.1/8.0 MB 1.7 MB/s eta 0:00:05
#     --------------------------------------- 0.1/8.0 MB 1.7 MB/s eta 0:00:05
#     --------------------------------------- 0.1/8.0 MB 1.7 MB/s eta 0:00:05
#    - -------------------------------------- 0.3/8.0 MB 944.1 kB/s eta 0:00:09
#    - -------------------------------------- 0.3/8.0 MB 944.1 kB/s eta 0:00:09
#    - -------------------------------------- 0.3/8.0 MB 759.5 kB/s eta 0:00:11
#    -- ------------------------------------- 0.4/8.0 MB 829.7 kB/s eta 0:00:10
#    -- ------------------------------------- 0.5/8.0 MB 893.0 kB/s eta 0:00:09
#    -- ------------------------------------- 0.6/8.0 MB 930.9 kB/s eta 0:00:08
#    --- ------------------------------------ 0.7/8.0 MB 997.5 kB/s eta 0:00:08
#    --- ------------------------------------ 0.7/8.0 MB 1.0 MB/s eta 0:00:08
#    --- ------------------------------------ 0.8/8.0 MB 1.0 MB/s eta 0:00:08
#    --- ------------------------------------ 0.8/8.0 MB 1.0 MB/s eta 0:00:08
#    ---- ----------------------------------- 0.9/8.0 MB 971.3 kB/s eta 0:00:08
#    ---- ----------------------------------- 1.0/8.0 MB 1.0 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.1/8.0 MB 1.0 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.1/8.0 MB 1.1 MB/s eta 0:00:07
#    ------ --------------------------------- 1.2/8.0 MB 1.1 MB/s eta 0:00:07
#    ------ --------------------------------- 1.3/8.0 MB 1.1 MB/s eta 0:00:07
#    ------ --------------------------------- 1.4/8.0 MB 1.1 MB/s eta 0:00:06
#    ------- -------------------------------- 1.5/8.0 MB 1.1 MB/s eta 0:00:06
#    ------- -------------------------------- 1.5/8.0 MB 1.1 MB/s eta 0:00:06
#    ------- -------------------------------- 1.6/8.0 MB 1.1 MB/s eta 0:00:06
#    -------- ------------------------------- 1.6/8.0 MB 1.1 MB/s eta 0:00:06
#    -------- ------------------------------- 1.8/8.0 MB 1.2 MB/s eta 0:00:06
#    --------- ------------------------------ 1.8/8.0 MB 1.2 MB/s eta 0:00:06
#    --------- ------------------------------ 1.9/8.0 MB 1.2 MB/s eta 0:00:06
#    --------- ------------------------------ 2.0/8.0 MB 1.2 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.0/8.0 MB 1.2 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.1/8.0 MB 1.2 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.3/8.0 MB 1.2 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.3/8.0 MB 1.2 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.4/8.0 MB 1.2 MB/s eta 0:00:05
#    ------------ --------------------------- 2.4/8.0 MB 1.2 MB/s eta 0:00:05
#    ------------ --------------------------- 2.5/8.0 MB 1.2 MB/s eta 0:00:05
#    ------------ --------------------------- 2.6/8.0 MB 1.2 MB/s eta 0:00:05
#    ------------- -------------------------- 2.7/8.0 MB 1.2 MB/s eta 0:00:05
#    ------------- -------------------------- 2.7/8.0 MB 1.2 MB/s eta 0:00:05
#    -------------- ------------------------- 2.8/8.0 MB 1.2 MB/s eta 0:00:05
#    -------------- ------------------------- 2.9/8.0 MB 1.2 MB/s eta 0:00:05
#    -------------- ------------------------- 2.9/8.0 MB 1.2 MB/s eta 0:00:05
#    --------------- ------------------------ 3.0/8.0 MB 1.2 MB/s eta 0:00:05
#    --------------- ------------------------ 3.1/8.0 MB 1.2 MB/s eta 0:00:05
#    ---------------- ----------------------- 3.2/8.0 MB 1.2 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.3/8.0 MB 1.2 MB/s eta 0:00:04
#    ----------------- ---------------------- 3.5/8.0 MB 1.2 MB/s eta 0:00:04
#    ----------------- ---------------------- 3.5/8.0 MB 1.2 MB/s eta 0:00:04
#    ------------------ --------------------- 3.6/8.0 MB 1.2 MB/s eta 0:00:04
#    ------------------ --------------------- 3.7/8.0 MB 1.2 MB/s eta 0:00:04
#    ------------------- -------------------- 3.8/8.0 MB 1.2 MB/s eta 0:00:04
#    ------------------- -------------------- 3.9/8.0 MB 1.2 MB/s eta 0:00:04
#    ------------------- -------------------- 4.0/8.0 MB 1.2 MB/s eta 0:00:04
#    -------------------- ------------------- 4.1/8.0 MB 1.2 MB/s eta 0:00:04
#    -------------------- ------------------- 4.2/8.0 MB 1.2 MB/s eta 0:00:04
#    --------------------- ------------------ 4.3/8.0 MB 1.2 MB/s eta 0:00:03
#    --------------------- ------------------ 4.3/8.0 MB 1.2 MB/s eta 0:00:03
#    ---------------------- ----------------- 4.4/8.0 MB 1.2 MB/s eta 0:00:03
#    ---------------------- ----------------- 4.5/8.0 MB 1.2 MB/s eta 0:00:03
#    ----------------------- ---------------- 4.6/8.0 MB 1.2 MB/s eta 0:00:03
#    ----------------------- ---------------- 4.7/8.0 MB 1.2 MB/s eta 0:00:03
#    ----------------------- ---------------- 4.8/8.0 MB 1.2 MB/s eta 0:00:03
#    ------------------------ --------------- 4.8/8.0 MB 1.2 MB/s eta 0:00:03
#    ------------------------ --------------- 4.9/8.0 MB 1.2 MB/s eta 0:00:03
#    ------------------------- -------------- 5.0/8.0 MB 1.2 MB/s eta 0:00:03
#    ------------------------- -------------- 5.1/8.0 MB 1.3 MB/s eta 0:00:03
#    ------------------------- -------------- 5.2/8.0 MB 1.3 MB/s eta 0:00:03
#    -------------------------- ------------- 5.3/8.0 MB 1.3 MB/s eta 0:00:03
#    -------------------------- ------------- 5.4/8.0 MB 1.3 MB/s eta 0:00:03
#    --------------------------- ------------ 5.4/8.0 MB 1.3 MB/s eta 0:00:02
#    --------------------------- ------------ 5.5/8.0 MB 1.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.6/8.0 MB 1.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.7/8.0 MB 1.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 5.8/8.0 MB 1.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 5.8/8.0 MB 1.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 5.9/8.0 MB 1.3 MB/s eta 0:00:02
#    ------------------------------ --------- 6.0/8.0 MB 1.3 MB/s eta 0:00:02
#    ------------------------------ --------- 6.1/8.0 MB 1.3 MB/s eta 0:00:02
#    ------------------------------- -------- 6.2/8.0 MB 1.3 MB/s eta 0:00:02
#    ------------------------------- -------- 6.3/8.0 MB 1.3 MB/s eta 0:00:02
#    ------------------------------- -------- 6.4/8.0 MB 1.3 MB/s eta 0:00:02
#    -------------------------------- ------- 6.5/8.0 MB 1.3 MB/s eta 0:00:02
#    -------------------------------- ------- 6.6/8.0 MB 1.3 MB/s eta 0:00:02
#    --------------------------------- ------ 6.7/8.0 MB 1.3 MB/s eta 0:00:02
#    --------------------------------- ------ 6.7/8.0 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.8/8.0 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.9/8.0 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.0/8.0 MB 1.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.1/8.0 MB 1.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.1/8.0 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 7.2/8.0 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.0 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 7.4/8.0 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 7.4/8.0 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 7.5/8.0 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 7.6/8.0 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 7.7/8.0 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 7.7/8.0 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 7.7/8.0 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 7.8/8.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  8.0/8.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  8.0/8.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 1.2 MB/s eta 0:00:00
# Downloading contourpy-1.2.1-cp311-cp311-win_amd64.whl (188 kB)
#    ---------------------------------------- 0.0/188.2 kB ? eta -:--:--
#    -------- ------------------------------- 41.0/188.2 kB 1.9 MB/s eta 0:00:01
#    ------------------------------------- -- 174.1/188.2 kB 1.3 MB/s eta 0:00:01
#    -------------------------------------- 188.2/188.2 kB 946.5 kB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.53.0-cp311-cp311-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    - -------------------------------------- 0.1/2.2 MB 2.6 MB/s eta 0:00:01
#    -- ------------------------------------- 0.2/2.2 MB 1.5 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.2/2.2 MB 1.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.3/2.2 MB 1.2 MB/s eta 0:00:02
#    ------ --------------------------------- 0.4/2.2 MB 1.1 MB/s eta 0:00:02
#    ------- -------------------------------- 0.4/2.2 MB 1.1 MB/s eta 0:00:02
#    -------- ------------------------------- 0.5/2.2 MB 1.1 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.6/2.2 MB 1.1 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.6/2.2 MB 1.1 MB/s eta 0:00:02
#    ------------- -------------------------- 0.7/2.2 MB 1.2 MB/s eta 0:00:02
#    --------------- ------------------------ 0.8/2.2 MB 1.2 MB/s eta 0:00:02
#    --------------- ------------------------ 0.9/2.2 MB 1.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 0.9/2.2 MB 1.1 MB/s eta 0:00:02
#    ------------------ --------------------- 1.0/2.2 MB 1.1 MB/s eta 0:00:02
#    ------------------- -------------------- 1.1/2.2 MB 1.1 MB/s eta 0:00:01
#    --------------------- ------------------ 1.2/2.2 MB 1.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.2/2.2 MB 1.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.3/2.2 MB 1.1 MB/s eta 0:00:01
#    ------------------------- -------------- 1.4/2.2 MB 1.2 MB/s eta 0:00:01
#    -------------------------- ------------- 1.4/2.2 MB 1.1 MB/s eta 0:00:01
#    -------------------------- ------------- 1.5/2.2 MB 1.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.6/2.2 MB 1.1 MB/s eta 0:00:01
#    ------------------------------ --------- 1.7/2.2 MB 1.2 MB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.2 MB 1.2 MB/s eta 0:00:01
#    --------------------------------- ------ 1.8/2.2 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.9/2.2 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------ --- 2.0/2.2 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 2.1/2.2 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 1.2 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.1 kB ? eta -:--:--
#    ------------------------------------ --- 51.2/56.1 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 56.1/56.1 kB 728.2 kB/s eta 0:00:00
# Downloading pillow-10.3.0-cp311-cp311-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    - -------------------------------------- 0.1/2.5 MB 2.3 MB/s eta 0:00:02
#    -- ------------------------------------- 0.2/2.5 MB 1.5 MB/s eta 0:00:02
#    --- ------------------------------------ 0.2/2.5 MB 1.5 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.3/2.5 MB 1.4 MB/s eta 0:00:02
#    ------ --------------------------------- 0.4/2.5 MB 1.3 MB/s eta 0:00:02
#    ------- -------------------------------- 0.5/2.5 MB 1.3 MB/s eta 0:00:02
#    -------- ------------------------------- 0.5/2.5 MB 1.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.6/2.5 MB 1.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.8/2.5 MB 1.4 MB/s eta 0:00:02
#    ------------- -------------------------- 0.8/2.5 MB 1.4 MB/s eta 0:00:02
#    -------------- ------------------------- 0.9/2.5 MB 1.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 1.0/2.5 MB 1.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 1.1/2.5 MB 1.4 MB/s eta 0:00:02
#    ------------------ --------------------- 1.2/2.5 MB 1.3 MB/s eta 0:00:01
#    ------------------- -------------------- 1.2/2.5 MB 1.4 MB/s eta 0:00:01
#    ------------------- -------------------- 1.2/2.5 MB 1.4 MB/s eta 0:00:01
#    ------------------- -------------------- 1.2/2.5 MB 1.2 MB/s eta 0:00:02
#    -------------------- ------------------- 1.3/2.5 MB 1.2 MB/s eta 0:00:02
#    ------------------------ --------------- 1.6/2.5 MB 1.3 MB/s eta 0:00:01
#    ------------------------ --------------- 1.6/2.5 MB 1.3 MB/s eta 0:00:01
#    -------------------------- ------------- 1.7/2.5 MB 1.3 MB/s eta 0:00:01
#    --------------------------- ------------ 1.7/2.5 MB 1.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.8/2.5 MB 1.2 MB/s eta 0:00:01
#    ------------------------------ --------- 1.9/2.5 MB 1.3 MB/s eta 0:00:01
#    ------------------------------- -------- 2.0/2.5 MB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.5 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.2/2.5 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 2.3/2.5 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 2.4/2.5 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 2.4/2.5 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 2.4/2.5 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 2.5/2.5 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  2.5/2.5 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 1.2 MB/s eta 0:00:00
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.2 kB ? eta -:--:--
#    ----------------------- ---------------- 61.4/103.2 kB 1.6 MB/s eta 0:00:01
#    -------------------------------------  102.4/103.2 kB 980.4 kB/s eta 0:00:01
#    -------------------------------------- 103.2/103.2 kB 744.0 kB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.0 kiwisolver-1.4.5 matplotlib-3.9.0 pillow-10.3.0 pyparsing-3.1.2

# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ---------------------------------------- 0.0/232.6 kB ? eta -:--:--
#    ----- ---------------------------------- 30.7/232.6 kB ? eta -:--:--
#    --------------- ----------------------- 92.2/232.6 kB 871.5 kB/s eta 0:00:01
#    -------------------- ----------------- 122.9/232.6 kB 654.9 kB/s eta 0:00:01
#    ------------------------- ------------ 153.6/232.6 kB 706.2 kB/s eta 0:00:01
#    ------------------------------------ - 225.3/232.6 kB 765.3 kB/s eta 0:00:01
#    -------------------------------------- 232.6/232.6 kB 646.3 kB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
from typing import List
import PyPDF2

def read_pdf(file_path: str) -> List[str]:
    with open(file_path, 'rb') as file:  # The 'b' in 'rb' stands for binary mode
        reader: PyPDF2.PdfReader = PyPDF2.PdfReader(file)
        # print(list(reader))
        text_content: List[str] = [page.extract_text() for page in reader.pages]
        return text_content

pages: list[str] = read_pdf("./Resume.pdf")
pages
# Out:
# ['M u h a m m a d\nw a q a s\nI\nam\na\nweb\ndeveloper\nwith\nover\n3\nyears\nof\nexperience.\nI\nspecialize\nin\ndeveloping\nresponsive\nwebsites\nfor\nall\ndevices\nand\nsolving\ncomplex\nproblems.\nI\nam\nalso\nadept\nat\nlearning\nnew\ntechnologies\naccording\nto\nmarket\ndemand..\nArea\n44c,\nhouse\n858\nKarachi\npakistan.\n+923101165278\nansariwaqas310@gmail.com\nhttps://github.com/waqasans\narii\nEXPERIENCE\nS m a s h\nc o d e ,\nRemote—\nSenior\nFull\nstack\ndeveloper\nS e p\n2 0 2 0\n-\nA p r\n2 0 2 4\nEDUCATION\nG o v t .\nb o y s\nS c h o o l ,\nKarachi\nPakistan—\nMatric\nf e b\n2 0 1 4 -\na p r i l\n2 0 1 6\nG o v t .\nB o y e\nS c i e n c e\nC o l l e g e ,\nKarachi\nPakistan—\nInter\na p r i l\n2 0 1 6\n-\na u g u s t\n2 0 1 8\nF U U A S T ,\nKarachi\nPakistan—\nBS\nMathematics\nF e b\n2 0 1 9\n-\nf e b\n2 0 2 3\nPROJECTS\nC r y p t o\nZ\nI\nam\ncreating\nDapp\nusing\nlens\nAPI,\nReactjs,\nIpfs,\nﬁrebaseDB\nand\nNodejs.\nIn\nwhich\nusers\ncan\ncreate\nstories\nwhich\ndepend\non\nepisodes\nand\nepisodes\ndepend\non\na\nmaximum\nof\n200\nposts.\nUsers\ncan\nconnect\ntheir\nmetamask\nwallet\nand\ncan\nread\nstories\n,\nlike\nposts\n,\ncomment\non\nposts.User\ncan\nwrite\na\nmaximum\n200\nposts\nand\nschedule\nthe\ndaily\nposts.\nhttps://www.crypto-z.com/\nE c o m m e r c e\nw e b\nI\ndeveloped\nan\necommerce\nwebsite\nusing\nNextjs(frontend\nand\nbackend), \nsanity\n,postgres\nvercel.\nSKILLS\n \nReactJs\n \nNextjs\n \nNextjs\nAPIs\n \nPostgres\n \nExpressjs\n \nNodejs\n \nDrizzle\norm\n \nJavaScript\n \nSolidity\n \nBlockchain\n \nIPFS\n \nWeb3\n \nRedux\ntoolkit\n \nRest\nAPI\n \nGraphQl\n \nEtherjs\n \nTypeScript\n \nFirebase\n \nTailwind\ncss\n \nHtml\n \nCss\n \nWallet\nintegration\n \nSmart\ncontract\nintegration\nPython\n(learning)\n ',
#  'https://fullstack-ecommerce-one.vercel.app/\nM i n t i n g\nw e b\nI\ndeveloped\na\nNFT\nmint\nwebsite\nusing\nNextjs\nand\nweb3.\nI\nwrote\nsmart \ncontracts\nfor\nerc721.\nhttps://pako-nf.vercel.app/\nC o u r s e\nw e b\nI\ndeveloped\na\ncourse\nwebsite\nusing\nNextjs(frontend\nand\nbackend),\nsanity \nand\nvercelDB.\nhttps://edumate-test.vercel.app/\nE n o u c t e r\nw e b\nI\ndeveloped\nan\nauction\nwebsite\nusing\nreactjs,\netherjs,\nipfs,\nnodejs\n,\nand \nﬁrebase.\nhttps://crypto-z-agency.netlify.app/\nLANGUAGES\nUrdu\nEnglish\nT e l l\nI t\nT o g e t h e r\nw e b\nhttps://smashcode-tellittogether.netlify.app/\nR e t a s k A I\nw e b\nhttps://smashcode-retaskai.netlify.app/dashboard/Write']

# %%
# reading pdf file
import PyPDF2

with open('./Resume.pdf', 'rb') as f:
    reader = PyPDF2.PdfReader(f)
    text = reader.pages[0].extract_text()
    print(text)
# Out:
# M u h a m m a d
# w a q a s
# I
# am
# a
# web
# developer
# with
# over
# 3
# years
# of
# experience.
# I
# specialize
# in
# developing
# responsive
# websites
# for
# all
# devices
# and
# solving
# complex
# problems.
# I
# am
# also
# adept
# at
# learning
# new
# technologies
# according
# to
# market
# demand..
# Area
# 44c,
# house
# 858
# Karachi
# pakistan.
# +923101165278
# ansariwaqas310@gmail.com
# https://github.com/waqasans
# arii
# EXPERIENCE
# S m a s h
# c o d e ,
# Remote—
# Senior
# Full
# stack
# developer
# S e p
# 2 0 2 0
# -
# A p r
# 2 0 2 4
# EDUCATION
# G o v t .
# b o y s
# S c h o o l ,
# Karachi
# Pakistan—
# Matric
# f e b
# 2 0 1 4 -
# a p r i l
# 2 0 1 6
# G o v t .
# B o y e
# S c i e n c e
# C o l l e g e ,
# Karachi
# Pakistan—
# Inter
# a p r i l
# 2 0 1 6
# -
# a u g u s t
# 2 0 1 8
# F U U A S T ,
# Karachi
# Pakistan—
# BS
# Mathematics
# F e b
# 2 0 1 9
# -
# f e b
# 2 0 2 3
# PROJECTS
# C r y p t o
# Z
# I
# am
# creating
# Dapp
# using
# lens
# API,
# Reactjs,
# Ipfs,
# ﬁrebaseDB
# and
# Nodejs.
# In
# which
# users
# can
# create
# stories
# which
# depend
# on
# episodes
# and
# episodes
# depend
# on
# a
# maximum
# of
# 200
# posts.
# Users
# can
# connect
# their
# metamask
# wallet
# and
# can
# read
# stories
# ,
# like
# posts
# ,
# comment
# on
# posts.User
# can
# write
# a
# maximum
# 200
# posts
# and
# schedule
# the
# daily
# posts.
# https://www.crypto-z.com/
# E c o m m e r c e
# w e b
# I
# developed
# an
# ecommerce
# website
# using
# Nextjs(frontend
# and
# backend),
# sanity
# ,postgres
# vercel.
# SKILLS
#
# ReactJs
#
# Nextjs
#
# Nextjs
# APIs
#
# Postgres
#
# Expressjs
#
# Nodejs
#
# Drizzle
# orm
#
# JavaScript
#
# Solidity
#
# Blockchain
#
# IPFS
#
# Web3
#
# Redux
# toolkit
#
# Rest
# API
#
# GraphQl
#
# Etherjs
#
# TypeScript
#
# Firebase
#
# Tailwind
# css
#
# Html
#
# Css
#
# Wallet
# integration
#
# Smart
# contract
# integration
# Python
# (learning)

# %% [markdown]
# # Reading Audio Files
# * You can use the pydub library to read audio files.

# %%
from pydub import AudioSegment

audio = AudioSegment.from_file("file.mp3")
print("Channels:", audio.channels)
print("Sample Width:", audio.sample_width)
print("Frame Rate:", audio.frame_rate)
print("Frame Width:", audio.frame_width)
print("Length (ms):", len(audio))
print("Frame Count:", audio.frame_count())

# %%
# !pip install pydub
# Out:
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1
